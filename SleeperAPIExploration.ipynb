# %%
import requests
import json
import pandas as pd
from bs4 import BeautifulSoup
from io import StringIO

# %%
resp = requests.get('https://api.sleeper.app/v1/user/noahschuit')

# %%
resp.json()
# Out:
# {'avatar': '52f03b0b35e1adf7ff576b317266abb4',
#  'cookies': None,
#  'created': None,
#  'currencies': None,
#  'data_updated': None,
#  'deleted': None,
#  'display_name': 'noahschuit',
#  'email': None,
#  'is_bot': False,
#  'metadata': None,
#  'notifications': None,
#  'pending': None,
#  'phone': None,
#  'real_name': None,
#  'solicitable': None,
#  'summoner_name': None,
#  'summoner_region': None,
#  'token': None,
#  'user_id': '867822229789040640',
#  'username': 'noahschuit',
#  'verification': None}

# %%
resp = requests.get('https://api.sleeper.app/v1/user/867822229789040640/leagues/nfl/2024')

# %%
resp.json()
# Out:
# [{'company_id': None,
#   'shard': 660,
#   'league_id': '1136863051997024256',
#   'previous_league_id': None,
#   'loser_bracket_overrides_id': None,
#   'last_author_display_name': 'sys',
#   'last_author_id': '166666666666666666',
#   'display_order': 0,
#   'last_message_id': '1180091132168667136',
#   'avatar': None,
#   'settings': {'last_report': 14,
#    'waiver_budget': 100,
#    'disable_adds': 0,
#    'capacity_override': 0,
#    'waiver_bid_min': 0,
#    'taxi_deadline': 0,
#    'draft_rounds': 3,
#    'reserve_allow_na': 0,
#    'start_week': 1,
#    'playoff_seed_type': 0,
#    'playoff_teams': 6,
#    'num_teams': 10,
#    'daily_waivers_hour': 6,
#    'playoff_type': 0,
#    'taxi_slots': 0,
#    'last_scored_leg': 17,
#    'daily_waivers_days': 9557,
#    'playoff_week_start': 15,
#    'waiver_clear_days': 2,
#    'reserve_allow_doubtful': 0,
#    'commissioner_direct_invite': 0,
#    'reserve_allow_dnr': 0,
#    'taxi_allow_vets': 0,
#    'waiver_day_of_week': 2,
# ...

# %%
league_id_2024 = "1124839329194082304"
league_id_2025 = '1258515704311709696'

# %%
resp = requests.get('https://api.sleeper.app/v1/league/1258515704311709696')

# %%
resp.json()
# Out:
# {'name': 'Any Given Sunday',
#  'status': 'in_season',
#  'metadata': {'auto_continue': 'on', 'keeper_deadline': '0'},
#  'settings': {'best_ball': 0,
#   'last_report': 4,
#   'waiver_budget': 100,
#   'disable_adds': 0,
#   'capacity_override': 0,
#   'waiver_bid_min': 0,
#   'taxi_deadline': 0,
#   'draft_rounds': 3,
#   'reserve_allow_na': 0,
#   'start_week': 1,
#   'playoff_seed_type': 1,
#   'playoff_teams': 6,
#   'veto_votes_needed': 6,
#   'num_teams': 12,
#   'daily_waivers_hour': 0,
#   'playoff_type': 1,
#   'taxi_slots': 0,
#   'sub_start_time_eligibility': 0,
#   'last_scored_leg': 4,
#   'daily_waivers_days': 5461,
#   'sub_lock_if_starter_active': 0,
#   'playoff_week_start': 15,
#   'waiver_clear_days': 1,
#   'reserve_allow_doubtful': 0,
#   'commissioner_direct_invite': 0,
#   'veto_auto_poll': 1,
#   'reserve_allow_dnr': 0,
#   'taxi_allow_vets': 0,
#   'waiver_day_of_week': 2,
#   'playoff_round_type': 0,
#   'reserve_allow_out': 0,
#   'reserve_allow_sus': 0,
# ...

# %%
resp = requests.get('https://api.sleeper.app/v1/league/1124839329194082304/rosters')

# %%
data = resp.json()
print(json.dumps(data, indent=2))
# Out:
# [
#   {
#     "co_owners": null,
#     "keepers": null,
#     "league_id": "1124839329194082304",
#     "metadata": {
#       "allow_pn_inactive_starters": "on",
#       "allow_pn_player_injury_status": "on",
#       "allow_pn_scoring": "off",
#       "restrict_pn_scoring_starters_only": "on"
#     },
#     "owner_id": null,
#     "player_map": null,
#     "players": null,
#     "reserve": null,
#     "roster_id": 1,
#     "settings": {
#       "fpts": 0,
#       "losses": 0,
#       "ties": 0,
#       "total_moves": 0,
#       "waiver_budget_used": 0,
#       "waiver_position": 11,
#       "wins": 0
#     },
#     "starters": [
#       "0",
#       "0",
#       "0",
#       "0",
#       "0",
#       "0",
#       "0",
#       "0",
#       "0"
#     ],
#     "taxi": null
#   },
#   {
#     "co_owners": null,
#     "keepers": null,
#     "league_id": "1124839329194082304",
#     "metadata": null,
#     "owner_id": "867943929876729856",
#     "player_map": null,
#     "players": null,
# ...

# %%
#players = requests.get('https://api.sleeper.app/v1/players/nfl').json()
#with open('players.json', 'w') as file:
#    json.dump(players, file, indent = 2)

# %%
df = pd.read_json('players.json', orient= 'index', convert_dates=False)
# Out:
# /tmp/ipykernel_3245/2213620535.py:1: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df = pd.read_json('players.json', orient= 'index', convert_dates=False)
# /tmp/ipykernel_3245/2213620535.py:1: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df = pd.read_json('players.json', orient= 'index', convert_dates=False)
# ...

# %%
df.to_csv("players.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11400 entries, 6462 to MIN
# Data columns (total 52 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   kalshi_id               3210 non-null   object
#  1   practice_participation  1 non-null      object
#  2   injury_start_date       0 non-null      float64
#  3   birth_date              10420 non-null  object
#  4   gsis_id                 3893 non-null   object
#  5   yahoo_id                6750 non-null   float64
#  6   fantasy_data_id         7461 non-null   float64
#  7   search_full_name        11368 non-null  object
#  8   espn_id                 6736 non-null   float64
#  9   height                  11354 non-null  object
#  10  depth_chart_order       1566 non-null   float64
#  11  rotowire_id             9720 non-null   float64
#  12  swish_id                5268 non-null   float64
#  13  pandascore_id           0 non-null      float64
# ...

# %%
resp = requests.get('https://api.sleeper.app/v1/league/1258515704311709696/matchups/6')

# %%
data = resp.json()
with open("sample.json", "w") as file:
    json.dump(data, file, indent= 4)

# %%
example_roster = {"players": [
    "11564",
    "11624",
    "12501",
    "12504",
    "12506",
    "12517",
    "3678",
    "4981",
    "6786",
    "7090",
    "7594",
    "8130",
    "9224",
    "9504",
    "9753",
    "NE"
    ]}

# %%
for player in example_roster['players']:
    print(df.loc[player][['full_name', 'fantasy_positions']])
# Out:
# full_name            Drake Maye
# fantasy_positions          [QB]
# Name: 11564, dtype: object
# full_name            Xavier Worthy
# fantasy_positions             [WR]
# Name: 11624, dtype: object
# full_name            Matthew Golden
# fantasy_positions              [WR]
# Name: 12501, dtype: object
# full_name            Kaleb Johnson
# fantasy_positions             [RB]
# Name: 12504, dtype: object
# full_name            Harold Fannin
# fantasy_positions             [TE]
# Name: 12506, dtype: object
# full_name            Colston Loveland
# fantasy_positions                [TE]
# Name: 12517, dtype: object
# full_name            Wil Lutz
# fantasy_positions         [K]
# Name: 3678, dtype: object
# full_name            Calvin Ridley
# fantasy_positions             [WR]
# Name: 4981, dtype: object
# full_name            CeeDee Lamb
# fantasy_positions           [WR]
# Name: 6786, dtype: object
# full_name            Darnell Mooney
# fantasy_positions              [WR]
# ...

# %%
df = pd.read_json("sample.json")
df.head()
df.to_csv("week_1_matchups.csv")
