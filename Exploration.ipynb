# %%
import requests
import json
import pandas as pd

# %%
resp = requests.get('https://api.sleeper.app/v1/user/noahschuit')

# %%
resp.json()
# Out:
# {'avatar': '52f03b0b35e1adf7ff576b317266abb4',
#  'cookies': None,
#  'created': None,
#  'currencies': None,
#  'data_updated': None,
#  'deleted': None,
#  'display_name': 'noahschuit',
#  'email': None,
#  'is_bot': False,
#  'metadata': None,
#  'notifications': None,
#  'pending': None,
#  'phone': None,
#  'real_name': None,
#  'solicitable': None,
#  'summoner_name': None,
#  'summoner_region': None,
#  'token': None,
#  'user_id': '867822229789040640',
#  'username': 'noahschuit',
#  'verification': None}

# %%
resp = requests.get('https://api.sleeper.app/v1/user/867822229789040640/leagues/nfl/2024')

# %%
resp.json()
# Out:
# [{'scoring_settings': {'sack': 1.0,
#    'fgm_40_49': 4.0,
#    'pass_int': -1.0,
#    'pts_allow_0': 10.0,
#    'pass_2pt': 2.0,
#    'st_td': 6.0,
#    'rec_td': 6.0,
#    'fgm_30_39': 3.0,
#    'fgm_50_59': 5.0,
#    'xpmiss': -1.0,
#    'rush_td': 6.0,
#    'rec_2pt': 2.0,
#    'st_fum_rec': 1.0,
#    'fgmiss': -1.0,
#    'ff': 1.0,
#    'rec': 1.0,
#    'pts_allow_14_20': 1.0,
#    'fgm_0_19': 3.0,
#    'int': 2.0,
#    'def_st_fum_rec': 1.0,
#    'fum_lost': -2.0,
#    'pts_allow_1_6': 7.0,
#    'fgm_60p': 6.0,
#    'fgm_20_29': 3.0,
#    'pts_allow_21_27': 0.0,
#    'xpm': 1.0,
#    'rush_2pt': 2.0,
#    'fum_rec': 2.0,
#    'def_st_td': 6.0,
#    'def_td': 6.0,
#    'safe': 2.0,
#    'pass_yd': 0.04,
#    'blk_kick': 2.0,
#    'pass_td': 4.0,
#    'rush_yd': 0.1,
#    'fum': 0.0,
#    'pts_allow_28_34': -1.0,
#    'pts_allow_35p': -4.0,
#    'fum_rec_td': 6.0,
#    'rec_yd': 0.1,
#    'def_st_ff': 1.0,
#    'pts_allow_7_13': 4.0,
#    'st_ff': 1.0},
# ...

# %%
league_id_2024 = "1124839329194082304"
league_id_2025 = '1258515704311709696'

# %%
resp = requests.get('https://api.sleeper.app/v1/league/1124839329194082304')

# %%
resp.json()
# Out:
# {'name': 'Any Given Sunday',
#  'status': 'complete',
#  'metadata': {'auto_continue': 'on',
#   'continued': 'yes',
#   'keeper_deadline': '0',
#   'latest_league_winner_roster_id': '3'},
#  'settings': {'best_ball': 0,
#   'waiver_budget': 100,
#   'disable_adds': 0,
#   'capacity_override': 0,
#   'waiver_bid_min': 0,
#   'taxi_deadline': 0,
#   'draft_rounds': 3,
#   'reserve_allow_na': 0,
#   'start_week': 1,
#   'playoff_seed_type': 1,
#   'playoff_teams': 8,
#   'veto_votes_needed': 6,
#   'num_teams': 12,
#   'daily_waivers_hour': 0,
#   'playoff_type': 1,
#   'taxi_slots': 0,
#   'daily_waivers_days': 5461,
#   'playoff_week_start': 15,
#   'waiver_clear_days': 1,
#   'reserve_allow_doubtful': 0,
#   'commissioner_direct_invite': 0,
#   'veto_auto_poll': 1,
#   'reserve_allow_dnr': 0,
#   'taxi_allow_vets': 0,
#   'waiver_day_of_week': 2,
#   'playoff_round_type': 0,
#   'reserve_allow_out': 0,
#   'reserve_allow_sus': 0,
#   'veto_show_votes': 0,
#   'trade_deadline': 11,
# ...

# %%
resp = requests.get('https://api.sleeper.app/v1/league/1258515704311709696/rosters')

# %%
data = resp.json()
print(json.dumps(data, indent=2))
# Out:
# [
#   {
#     "co_owners": null,
#     "keepers": null,
#     "league_id": "1258515704311709696",
#     "metadata": {
#       "allow_pn_inactive_starters": "on",
#       "allow_pn_player_injury_status": "on",
#       "allow_pn_scoring": "off",
#       "restrict_pn_scoring_starters_only": "on"
#     },
#     "owner_id": "867773438608187392",
#     "player_map": null,
#     "players": [
#       "11564",
#       "11577",
#       "11624",
#       "12501",
#       "12504",
#       "12517",
#       "3678",
#       "4981",
#       "6786",
#       "6804",
#       "7090",
#       "7594",
#       "8130",
#       "9224",
#       "9753",
#       "NE"
#     ],
#     "reserve": null,
#     "roster_id": 1,
#     "settings": {
#       "fpts": 0,
#       "losses": 0,
#       "ties": 0,
#       "total_moves": 0,
#       "waiver_budget_used": 0,
#       "waiver_position": 7,
#       "wins": 0
#     },
#     "starters": [
#       "11564",
#       "9224",
#       "7594",
#       "6786",
#       "11624",
# ...

# %%
#players = requests.get('https://api.sleeper.app/v1/players/nfl').json()

# %%
#with open('players.json', 'w') as file:
#    json.dump(players, file, indent = 2)

# %%
df = pd.read_json('players.json', orient= 'index')
# Out:
# /tmp/ipykernel_6527/721672800.py:1: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df = pd.read_json('players.json', orient= 'index')
# /tmp/ipykernel_6527/721672800.py:1: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df = pd.read_json('players.json', orient= 'index')
# ...

# %%
df.to_csv("players.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11400 entries, 6462 to MIN
# Data columns (total 52 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   news_updated            7551 non-null   float64
#  1   first_name              11400 non-null  object
#  2   injury_start_date       0 non-null      float64
#  3   birth_date              10408 non-null  object
#  4   team_changed_at         0 non-null      datetime64[ns]
#  5   yahoo_id                6750 non-null   float64
#  6   active                  11400 non-null  bool
#  7   pandascore_id           0 non-null      float64
#  8   opta_id                 0 non-null      float64
#  9   high_school             10089 non-null  object
#  10  practice_description    1 non-null      object
#  11  injury_body_part        1043 non-null   object
#  12  depth_chart_order       1552 non-null   float64
#  13  fantasy_data_id         7461 non-null   float64
# ...

# %%
resp = requests.get('https://api.sleeper.app/v1/league/1258515704311709696/matchups/1')

# %%
resp.json()
# Out:
# [{'points': 103.18,
#   'players': ['11564',
#    '11577',
#    '11624',
#    '12501',
#    '12504',
#    '12517',
#    '3678',
#    '4981',
#    '6786',
#    '6804',
#    '7090',
#    '7594',
#    '8130',
#    '9224',
#    '9753',
#    'NE'],
#   'roster_id': 1,
#   'custom_points': None,
#   'matchup_id': 5,
#   'starters': ['11564',
#    '9224',
#    '7594',
#    '6786',
#    '11624',
#    '4981',
#    '8130',
#    '12501',
#    '3678',
#    'NE'],
#   'starters_points': [16.78, 13.1, 17.9, 18.0, 0.0, 6.7, 12.1, 3.6, 8.0, 7.0],
#   'players_points': {'11564': 16.78,
#    '11577': 2.6,
#    '11624': 0.0,
#    '12501': 3.6,
#    '12504': -0.2,
#    '12517': 0.0,
#    '3678': 8.0,
#    '4981': 6.7,
#    '6786': 18.0,
#    '6804': 15.92,
#    '7090': 0.0,
#    '7594': 17.9,
#    '8130': 12.1,
#    '9224': 13.1,
#    '9753': 10.7,
#    'NE': 7.0}},
#  {'points': 92.12,
#   'players': ['11533',
#    '11575',
#    '12481',
#    '12530',
#    '1479',
#    '4217',
#    '5947',
# ...
